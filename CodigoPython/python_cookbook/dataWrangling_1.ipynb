# %% [markdown]
# <a href="https://colab.research.google.com/github/NightWingC/data-science/blob/main/CodigoPython/python_cookbook/dataWrangling_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load library
import pandas as pd
import numpy as np

# Create URL
url = "https://raw.githubusercontent.com/chrisalbon/sim_data/master/titanic.csv"

# Load data as a dataframe
df_titanic = pd.read_csv(url)
df_titanic.head(5)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
# Creating a DataFrame
dictonary = { "Name": ["Jacky Jackson", "Steven Stevenson"],
             "Age": [38,25],
              "Driver": [True, False],
            }
dataframe = pd.DataFrame(dictonary)
dataframe
# Out:
#                Name  Age  Driver
# 0     Jacky Jackson   38    True
# 1  Steven Stevenson   25   False

# %%
# Add a column for eye color
dataframe["Eyes"] = ["Browns", "Blue"]
dataframe
# Out:
#                Name  Age  Driver    Eyes
# 0     Jacky Jackson   38    True  Browns
# 1  Steven Stevenson   25   False    Blue

# %%
# Getting information about Data
df_titanic.head(2)

# show dimensions
df_titanic.shape

# Show statistics
df_titanic.describe()

# Show info
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1313 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
#  5   SexCode   1313 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 61.7+ KB

# %%
# Slicing DataFrames
dataframe.iloc[0]
# Out:
# Name      Jacky Jackson
# Age                  38
# Driver             True
# Eyes             Browns
# Name: 0, dtype: object

# %%
# Select tree rows
df_titanic.iloc[2:5]
# Out:
#                                             Name PClass    Age     Sex  \
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 2         0        0
# 3         0        1
# 4         1        0

# %%
# Select four rows
df_titanic.iloc[:4]
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Set index
df_titanic = df_titanic.set_index(df_titanic["Name"])
# Show row
df_titanic.loc["Allen, Miss Elisabeth Walton"]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: Allen, Miss Elisabeth Walton, dtype: object

# %%
# Selecting Rows based onn conditionals
df_titanic[df_titanic["Sex"] == "female"].head(3)
# Out:
#                                                                                         Name  \
# Name
# Allen, Miss Elisabeth Walton                                    Allen, Miss Elisabeth Walton
# Allison, Miss Helen Loraine                                      Allison, Miss Helen Loraine
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)  Allison, Mrs Hudson JC (Bessie Waldo Daniels)
#
#                                               PClass   Age     Sex  Survived  \
# Name
# Allen, Miss Elisabeth Walton                     1st  29.0  female         1
# Allison, Miss Helen Loraine                      1st   2.0  female         0
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female         0
#
#                                                SexCode
# Name
# Allen, Miss Elisabeth Walton                         1
# Allison, Miss Helen Loraine                          1
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)        1

# %%
# Filter rows
df_titanic[(df_titanic["Sex"] == "female") & (df_titanic["Age"] >= 65)]
# Out:
#                                                                                                  Name  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...  Crosby, Mrs Edward Gifford (Catherine Elizabet...
#
#                                                    PClass   Age     Sex  \
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...    1st  69.0  female
#
#                                                     Survived  SexCode
# Name
# Crosby, Mrs Edward Gifford (Catherine Elizabeth...         1        1

# %%
# Sorting Values
# Sort the dataframe by age, show, two rows
df_titanic.sort_values(by=["Age"]).head(2)
# Out:
#                                                                           Name  \
# Name
# Dean, Miss Elizabeth Gladys (Millvena)  Dean, Miss Elizabeth Gladys (Millvena)
# Danbom, Master Gilbert Sigvard Emanuel  Danbom, Master Gilbert Sigvard Emanuel
#
#                                        PClass   Age     Sex  Survived  SexCode
# Name
# Dean, Miss Elizabeth Gladys (Millvena)    3rd  0.17  female         1        1
# Danbom, Master Gilbert Sigvard Emanuel    3rd  0.33    male         0        0

# %%
# Replacing Values
df_titanic["Sex"].replace("female", "Woman").head(3)
# Out:
# Name
# Allen, Miss Elisabeth Walton           Woman
# Allison, Miss Helen Loraine            Woman
# Allison, Mr Hudson Joshua Creighton     male
# Name: Sex, dtype: object

# %%
# Replace "female" and "male" with "Woman" and "Man"
df_titanic["Sex"].replace(["female","male"],["Woman","Man"]).head(4)
# Out:
# Name
# Allen, Miss Elisabeth Walton                     Woman
# Allison, Miss Helen Loraine                      Woman
# Allison, Mr Hudson Joshua Creighton                Man
# Allison, Mrs Hudson JC (Bessie Waldo Daniels)    Woman
# Name: Sex, dtype: object

# %%
# Replace values, show two rows
df_titanic.replace(1, "One").head(2)
# Out:
#                                                       Name PClass   Age  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton    1st  29.0
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine    1st   2.0
#
#                                  Sex Survived SexCode
# Name
# Allen, Miss Elisabeth Walton  female      One     One
# Allison, Miss Helen Loraine   female        0     One

# %%
# Renaming columns
df_titanic.rename(columns={"PClass": "Passeger Class"}).head(2)
# Out:
#                                                       Name Passeger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton            1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine            1st
#
#                                Age     Sex  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1
# Allison, Miss Helen Loraine    2.0  female         0        1

# %%
df_titanic.rename(columns={"PClass": "Passeger Class", "Sex": "Gender"}).head(2)
# Out:
#                                                       Name Passeger Class  \
# Name
# Allen, Miss Elisabeth Walton  Allen, Miss Elisabeth Walton            1st
# Allison, Miss Helen Loraine    Allison, Miss Helen Loraine            1st
#
#                                Age  Gender  Survived  SexCode
# Name
# Allen, Miss Elisabeth Walton  29.0  female         1        1
# Allison, Miss Helen Loraine    2.0  female         0        1

# %%
# Finding minimum, maximum, sum, average and count
# Calculate statitics
print("Maximum:", df_titanic["Age"].max())
print("Minimum:", df_titanic["Age"].min())
print("Mean:", df_titanic["Age"].mean())
print("Sum:", df_titanic["Age"].sum())
print("Count:", df_titanic["Age"].count())
# Out:
# Maximum: 71.0
# Minimum: 0.17
# Mean: 30.397989417989418
# Sum: 22980.88
# Count: 756

# %%
# Finding unique values
df_titanic["Sex"].unique()
# array(["female","male"], dtype=object)

# Show counts
df_titanic["Sex"].value_counts()
# Out:
# Sex
# male      851
# female    462
# Name: count, dtype: int64

# %%
df_titanic["PClass"].value_counts()
# Out:
# PClass
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: count, dtype: int64

# %%
# Show number of unique values
df_titanic["PClass"].nunique()
# Out:
# 4

# %%
# Handling missing values
df_titanic[df_titanic["Age"].isnull()].head(5)
# Out:
#                                                       Name PClass  Age  \
# Name
# Aubert, Mrs Leontine Pauline  Aubert, Mrs Leontine Pauline    1st  NaN
# Barkworth, Mr Algernon H          Barkworth, Mr Algernon H    1st  NaN
# Baumann, Mr John D                      Baumann, Mr John D    1st  NaN
# Borebank, Mr John James            Borebank, Mr John James    1st  NaN
# Bradley, Mr George                      Bradley, Mr George    1st  NaN
#
#                                  Sex  Survived  SexCode
# Name
# Aubert, Mrs Leontine Pauline  female         1        1
# Barkworth, Mr Algernon H        male         1        0
# Baumann, Mr John D              male         0        0
# Borebank, Mr John James         male         0        0
# Bradley, Mr George              male         1        0

# %%
#  Attempt to replace values with NaN
df_titanic["Sex"] = df_titanic["Sex"].replace("male", NaN)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-37-437144425.py in <cell line: 0>()
#       1 #  Attempt to replace values with NaN
# ----> 2 df_titanic["Sex"] = df_titanic["Sex"].replace("male", NaN)
#
# NameError: name 'NaN' is not defined

# %%
# Load library
import numpy as np

# Replace value with NaN
df_titanic["Sex"] = df_titanic["Sex"].replace("male", np.nan)

# %%
# Load data, set missing values
dataframe2 = pd.read_csv(url, na_values=[np.nan, "None", -999])
dataframe2.head(10)
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
# 5                             Anderson, Mr Harry    1st  47.00    male
# 6               Andrews, Miss Kornelia Theodosia    1st  63.00  female
# 7                         Andrews, Mr Thomas, jr    1st  39.00    male
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.00  female
# 9                         Artagaveytia, Mr Ramon    1st  71.00    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0
# 5         1        0
# 6         1        1
# ...

# %%
# get a single null value
null_entry = df_titanic[df_titanic["Age"].isna()].head(1)
print(null_entry)
# Out:
#                                                       Name PClass  Age  \
# Name
# Aubert, Mrs Leontine Pauline  Aubert, Mrs Leontine Pauline    1st  NaN
#
#                                  Sex  Survived  SexCode
# Name
# Aubert, Mrs Leontine Pauline  female         1        1

# %%
# Fill all null values with the mean age of passengers
null_entry.fillna(df_titanic["Age"].mean())
# Out:
#                                                       Name PClass        Age  \
# Name
# Aubert, Mrs Leontine Pauline  Aubert, Mrs Leontine Pauline    1st  30.397989
#
#                                  Sex  Survived  SexCode
# Name
# Aubert, Mrs Leontine Pauline  female         1        1

# %%
# Deleting a column
df_titanic.drop("Age", axis=1).head(2)
# Out:
#                            Name PClass     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st  female         1        1
# 1   Allison, Miss Helen Loraine    1st  female         0        1

# %%
# Drop colums
df_titanic.drop(["Age", "Sex"], axis=1).head(2)
# Out:
#                            Name PClass  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton    1st         1        1
# 1   Allison, Miss Helen Loraine    1st         0        1

# %%
# if the column does not have a name
df_titanic.drop(df_titanic.columns[1], axis=1).head(2)
# Out:
#                            Name   Age     Sex  Survived  SexCode
# 0  Allen, Miss Elisabeth Walton  29.0  female         1        1
# 1   Allison, Miss Helen Loraine   2.0  female         0        1

# %%
# Deleting a row
df_titanic[df_titanic["Sex"] != "male"].head(3)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 3         0        1

# %%
# Delete row, show first two rows of output
df_titanic[df_titanic["Name"] != "Allison, Miss Helen Loraine"].head(2)
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
# Dropping duplicate rows
df_titanic.drop_duplicates().head(4)
# Out:
#                                             Name PClass   Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.0  female
# 1                    Allison, Miss Helen Loraine    1st   2.0  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.0    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.0  female
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1

# %%
# Show number of rows
print("Number of rows in the original dataframe")
len(df_titanic)
print("Numbers of rows adter dropping")
len(df_titanic.drop_duplicates())
# Out:
# Number of rows in the original dataframe
# Numbers of rows adter dropping
# 1313

# %%
df_titanic.drop_duplicates(subset=["Sex"])
# Out:
#                                   Name PClass   Age     Sex  Survived  SexCode
# 0         Allen, Miss Elisabeth Walton    1st  29.0  female         1        1
# 2  Allison, Mr Hudson Joshua Creighton    1st  30.0    male         0        0

# %%
df_titanic.drop_duplicates(subset=["Sex"], keep="last")
# Out:
#                      Name PClass   Age     Sex  Survived  SexCode
# 1307  Zabour, Miss Tamini    3rd   NaN  female         0        1
# 1312       Zimmerman, Leo    3rd  29.0    male         0        0

# %%
# Grouping rows by values
# group rows by the values of the column "Sex", calculate mean # of each group
df_titanic.groupby("Sex").mean(numeric_only=True)
# Out:
#               Age  Survived  SexCode
# Sex
# female  29.396424  0.666667      1.0
# male    31.014338  0.166863      0.0

# %%
df_titanic.groupby("Survived")["Name"].count()
# Out:
# Survived
# 0    863
# 1    450
# Name: Name, dtype: int64

# %%
# Gropu rows, calculate mean
df_titanic.groupby(["Sex","Survived"])["Age"].mean()
# Out:
# Sex     Survived
# female  0           24.901408
#         1           30.867143
# male    0           32.320780
#         1           25.951875
# Name: Age, dtype: float64

# %%
# Grouping rows by time
time_index = pd.data_range("06/06/2017", periods=100000, freq="305")

# Create datframe
dataf = pd.DataFrame(index=time_index)

# Create column of random values
dataf["Sale_Amount"] = np.random.randint(1,10,100000)

# Group rows by week, calculate sun per week
dataf.resample("W").sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-17-2327571613.py in <cell line: 0>()
#       1 # Grouping rows by time
# ----> 2 time_index = pd.data_range("06/06/2017", periods=100000, freq="305")
#       3
#       4 # Create datframe
#       5 dataf = pd.DataFrame(index=time_index)
#
# AttributeError: module 'pandas' has no attribute 'data_range'
