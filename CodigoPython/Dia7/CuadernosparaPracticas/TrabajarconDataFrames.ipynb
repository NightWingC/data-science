# %%
import pandas as pd

# %%
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 22, 27],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}

df = pd.DataFrame(data)

# %%
df
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    25     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    22   Valencia
# 3    Sara    27     Bilbao

# %%
df["Salario"] = [30000, 45000, 32000,3800]
df
# Out:
#    Nombre  Edad     Ciudad  Salario
# 0     Ana    25     Madrid    30000
# 1    Luis    30  Barcelona    45000
# 2  Carlos    22   Valencia    32000
# 3    Sara    27     Bilbao     3800

# %%
df["Salario"] = df["Salario"] + 2000
df
# Out:
#    Nombre  Edad     Ciudad  Salario
# 0     Ana    25     Madrid    32000
# 1    Luis    30  Barcelona    47000
# 2  Carlos    22   Valencia    34000
# 3    Sara    27     Bilbao     5800

# %%
nombre = df["Nombre"]
nombre
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# 3      Sara
# Name: Nombre, dtype: object

# %%
mayores_25 = df["Edad" > 25]
mayores_25
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# Name: Edad, dtype: bool

# %%
edades = df["Edad"]
edades
# Out:
# 0    25
# 1    30
# 2    22
# 3    27
# Name: Edad, dtype: int64

# %%
mayores_25 = df[edades > 25]
mayores_25
# Out:
#   Nombre  Edad     Ciudad  Salario
# 1   Luis    30  Barcelona    47000
# 3   Sara    27     Bilbao     5800

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(edades)
# Out:
# pandas.core.series.Series

# %%
type(mayores_25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4-3646870935.py in <cell line: 0>()
# ----> 1 type(mayores_25)
#
# NameError: name 'mayores_25' is not defined

# %%
libros_df = {
    "titulos": ["El quijote", "Cien años de soledad","La odisea"],
    "autores": ["Miguel de Cervantes","Gabriel García Márquez", "Homero"],
    "Años publicación": [1605, 1957, -800]
}
librosDf = pd.DataFrame(libros_df)
librosDf
# Out:
#                 titulos                 autores  Años publicación
# 0            El quijote     Miguel de Cervantes              1605
# 1  Cien años de soledad  Gabriel García Márquez              1957
# 2             La odisea                  Homero              -800

# %%
# Datos proporcionados
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 22, 27],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}

dataframe25 = pd.DataFrame(data)
df_filtrado = dataframe25[dataframe25["Edad"] > 25]
df_filtrado
# Out:
#   Nombre  Edad     Ciudad
# 1   Luis    30  Barcelona
# 3   Sara    27     Bilbao

# %%
data = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'Sara'],
    'Edad': [25, 30, 22, 27],
    'Ciudad': ['Madrid', 'Barcelona', 'Valencia', 'Bilbao']
}

dftest = pd.DataFrame(data)
dftest["Ciudad"] = dftest["Ciudad"].str.upper()

dftest["Edad en 10 años"] = dftest["Edad"] + 10
dftest["Es Mayor de 25"] = dftest["Edad"] > 25
dftest
# Out:
#    Nombre  Edad     Ciudad  Edad en 10 años  Es Mayor de 25
# 0     Ana    25     MADRID               35           False
# 1    Luis    30  BARCELONA               40            True
# 2  Carlos    22   VALENCIA               32           False
# 3    Sara    27     BILBAO               37            True
